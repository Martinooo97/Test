# %%
print ("Aivi is super cool")
# Out:
# Aivi is super cool

# %%
type (10)
# Out:
# int

# %%
type(10.0
)
# Out:
# float

# %%
int(10.0)
# Out:
# 10

# %%
# Zelle zur markdown zelle machen ESC + M; und danach kann man ein Bild reinziehen

# %% [markdown]
# ![1371931.jpg](attachment:1371931.jpg)

# %%
list1 = [1,2,3]

# %%
list1.append("Hello")
print (list1)
# Out:
# [1, 2, 3, 'Hello']

# %%
list1 [2]
# Out:
# 3

# %%
list1 [3] = "x"
print (list1)
# Out:
# [1, 2, 3, 'x']

# %%
tuple1 = (4,5,6)
tuple1.index(5)
tuple1.append("Bye")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-dedb0a56c314> in <module>
#       1 tuple1 = (4,5,6)
#       2 tuple1.index(5)
# ----> 3 tuple1.append("Bye")
#
# AttributeError: 'tuple' object has no attribute 'append'
